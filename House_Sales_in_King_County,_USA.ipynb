# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
df = pd.read_csv("kc_house_data.csv")
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
df.drop(["id"],axis=1,inplace=True)
df.head(5)
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0         3       1.00         1180      5650
# 1  20141209T000000  538000.0         3       2.25         2570      7242
# 2  20150225T000000  180000.0         2       1.00          770     10000
# 3  20141209T000000  604000.0         4       3.00         1960      5000
# 4  20150218T000000  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503

# %%
df.describe(include="all")
# Out:
#                    date         price      bedrooms     bathrooms  \
# count             21613  2.161300e+04  21613.000000  21613.000000
# unique              372           NaN           NaN           NaN
# top     20140623T000000           NaN           NaN           NaN
# freq                142           NaN           NaN           NaN
# mean                NaN  5.400881e+05      3.370842      2.114757
# std                 NaN  3.671272e+05      0.930062      0.770163
# min                 NaN  7.500000e+04      0.000000      0.000000
# 25%                 NaN  3.219500e+05      3.000000      1.750000
# 50%                 NaN  4.500000e+05      3.000000      2.250000
# 75%                 NaN  6.450000e+05      4.000000      2.500000
# max                 NaN  7.700000e+06     33.000000      8.000000
#
#          sqft_living      sqft_lot        floors    waterfront          view  \
# count   21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean     2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# std       918.440897  4.142051e+04      0.539989      0.086517      0.766318
# min       290.000000  5.200000e+02      1.000000      0.000000      0.000000
# 25%      1427.000000  5.040000e+03      1.000000      0.000000      0.000000
# 50%      1910.000000  7.618000e+03      1.500000      0.000000      0.000000
# 75%      2550.000000  1.068800e+04      2.000000      0.000000      0.000000
# max     13540.000000  1.651359e+06      3.500000      1.000000      4.000000
#
#            condition         grade    sqft_above  sqft_basement      yr_built  \
# count   21613.000000  21613.000000  21613.000000   21613.000000  21613.000000
# unique           NaN           NaN           NaN            NaN           NaN
# top              NaN           NaN           NaN            NaN           NaN
# freq             NaN           NaN           NaN            NaN           NaN
# mean        3.409430      7.656873   1788.390691     291.509045   1971.005136
# std         0.650743      1.175459    828.090978     442.575043     29.373411
# min         1.000000      1.000000    290.000000       0.000000   1900.000000
# 25%         3.000000      7.000000   1190.000000       0.000000   1951.000000
# 50%         3.000000      7.000000   1560.000000       0.000000   1975.000000
# 75%         4.000000      8.000000   2210.000000     560.000000   1997.000000
# max         5.000000     13.000000   9410.000000    4820.000000   2015.000000
#
#         yr_renovated       zipcode           lat          long  sqft_living15  \
# count   21613.000000  21613.000000  21613.000000  21613.000000   21613.000000
# unique           NaN           NaN           NaN           NaN            NaN
# top              NaN           NaN           NaN           NaN            NaN
# freq             NaN           NaN           NaN           NaN            NaN
# mean       84.402258  98077.939805     47.560053   -122.213896    1986.552492
# std       401.679240     53.505026      0.138564      0.140828     685.391304
# min         0.000000  98001.000000     47.155900   -122.519000     399.000000
# 25%         0.000000  98033.000000     47.471000   -122.328000    1490.000000
# 50%         0.000000  98065.000000     47.571800   -122.230000    1840.000000
# 75%         0.000000  98118.000000     47.678000   -122.125000    2360.000000
# max      2015.000000  98199.000000     47.777600   -121.315000    6210.000000
#
#            sqft_lot15
# count    21613.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean     12768.455652
# std      27304.179631
# min        651.000000
# 25%       5100.000000
# 50%       7620.000000
# 75%      10083.000000
# max     871200.000000

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df_count=df["floors"].value_counts()
df_count
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
df_count.to_frame()
# Out:
#      floors
# 1.0   10680
# 2.0    8241
# 1.5    1910
# 3.0     613
# 2.5     161
# 3.5       8

# %%
sns.boxplot(x = 'waterfront',  y = 'price', data = df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
sns.boxplot(x = 'bedrooms',  y = 'price', data = df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
sns.boxplot(x = 'price', data = df)
# Out:
# <Axes: xlabel='price'>

# %%
sns.boxplot(x = 'bathrooms', data = df)
# Out:
# <Axes: xlabel='bathrooms'>

# %%
sns.boxplot(x = 'floors', data = df)
# Out:
# <Axes: xlabel='floors'>

# %%
sns.boxplot(x = 'condition', data = df)
# Out:
# <Axes: xlabel='condition'>

# %%
sns.boxplot(x = 'grade', data = df)
# Out:
# <Axes: xlabel='grade'>

# %%
sns.boxplot(x = 'yr_built', data = df)
# Out:
# <Axes: xlabel='yr_built'>

# %%
sns.boxplot(x = 'lat', data = df)
# Out:
# <Axes: xlabel='lat'>

# %%
sns.boxplot(x = 'long', data = df)
# Out:
# <Axes: xlabel='long'>

# %%
sns.regplot(x = 'sqft_above', y = 'price', data = df)
# Out:
# <Axes: xlabel='sqft_above', ylabel='price'>

# %%
sns.regplot(x = 'sqft_basement', y = 'price', data = df)
# Out:
# <Axes: xlabel='sqft_basement', ylabel='price'>

# %%
df.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('rainbow'), axis=1)
# Out:
# <ipython-input-25-2213f4ef076c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('rainbow'), axis=1)
# <style type="text/css">
# #T_680f0_row0_col0, #T_680f0_row1_col1, #T_680f0_row2_col2, #T_680f0_row3_col3, #T_680f0_row4_col4, #T_680f0_row5_col5, #T_680f0_row6_col6, #T_680f0_row7_col7, #T_680f0_row8_col8, #T_680f0_row9_col9, #T_680f0_row10_col10, #T_680f0_row11_col11, #T_680f0_row12_col12, #T_680f0_row13_col13, #T_680f0_row14_col14, #T_680f0_row15_col15, #T_680f0_row16_col16, #T_680f0_row17_col17, #T_680f0_row18_col18 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_680f0_row0_col1, #T_680f0_row0_col15, #T_680f0_row10_col7 {
#   background-color: #2fe0db;
#   color: #000000;
# }
# #T_680f0_row0_col2 {
#   background-color: #99fca6;
#   color: #000000;
# }
# #T_680f0_row0_col3, #T_680f0_row9_col2 {
#   background-color: #eec66d;
#   color: #000000;
# }
# #T_680f0_row0_col4, #T_680f0_row4_col6, #T_680f0_row13_col8, #T_680f0_row15_col7, #T_680f0_row18_col13 {
#   background-color: #3c68f9;
#   color: #f1f1f1;
# }
# #T_680f0_row0_col5, #T_680f0_row6_col0 {
#   background-color: #17cbe4;
#   color: #000000;
# }
# #T_680f0_row0_col6, #T_680f0_row12_col4 {
#   background-color: #1acfe3;
#   color: #000000;
# }
# #T_680f0_row0_col7, #T_680f0_row6_col7 {
#   background-color: #5af8c8;
#   color: #000000;
# }
# #T_680f0_row0_col8 {
#   background-color: #5641fd;
#   color: #f1f1f1;
# }
# #T_680f0_row0_col9, #T_680f0_row10_col0 {
#   background-color: #ded579;
#   color: #000000;
# }
# #T_680f0_row0_col10 {
#   background-color: #c0eb8d;
#   color: #000000;
# }
# #T_680f0_row0_col11, #T_680f0_row11_col17 {
#   background-color: #37e6d8;
#   color: #000000;
# }
# #T_680f0_row0_col12 {
#   background-color: #4c50fc;
#   color: #f1f1f1;
# }
# #T_680f0_row0_col13, #T_680f0_row7_col13, #T_680f0_row9_col13, #T_680f0_row15_col17 {
#   background-color: #2981f6;
#   color: #f1f1f1;
# }
# #T_680f0_row0_col14, #T_680f0_row1_col14, #T_680f0_row2_col14, #T_680f0_row3_col14, #T_680f0_row4_col14, #T_680f0_row5_col8, #T_680f0_row6_col16, #T_680f0_row7_col16, #T_680f0_row8_col12, #T_680f0_row9_col14, #T_680f0_row10_col14, #T_680f0_row11_col5, #T_680f0_row12_col8, #T_680f0_row13_col12, #T_680f0_row14_col16, #T_680f0_row15_col12, #T_680f0_row16_col14, #T_680f0_row17_col14, #T_680f0_row18_col14 {
#   background-color: #8000ff;
#   color: #f1f1f1;
# }
# #T_680f0_row0_col16, #T_680f0_row8_col5 {
#   background-color: #5c38fd;
#   color: #f1f1f1;
# }
# #T_680f0_row0_col17, #T_680f0_row2_col0 {
#   background-color: #b6f193;
#   color: #000000;
# }
# #T_680f0_row0_col18, #T_680f0_row1_col6, #T_680f0_row4_col11, #T_680f0_row13_col16, #T_680f0_row15_col10, #T_680f0_row18_col8 {
#   background-color: #4062fa;
#   color: #f1f1f1;
# }
# #T_680f0_row1_col0, #T_680f0_row14_col13 {
#   background-color: #4df3ce;
#   color: #000000;
# }
# #T_680f0_row1_col2, #T_680f0_row16_col10 {
#   background-color: #a8f79c;
#   color: #000000;
# }
# #T_680f0_row1_col3 {
#   background-color: #c2ea8c;
#   color: #000000;
# }
# #T_680f0_row1_col4, #T_680f0_row1_col8, #T_680f0_row1_col18, #T_680f0_row8_col9, #T_680f0_row12_col15 {
#   background-color: #3079f7;
#   color: #f1f1f1;
# }
# #T_680f0_row1_col5 {
#   background-color: #10c6e6;
#   color: #000000;
# }
# #T_680f0_row1_col7, #T_680f0_row5_col18, #T_680f0_row13_col10, #T_680f0_row18_col0 {
#   background-color: #1996f3;
#   color: #f1f1f1;
# }
# #T_680f0_row1_col9, #T_680f0_row16_col1 {
#   background-color: #62fbc4;
#   color: #000000;
# }
# #T_680f0_row1_col10, #T_680f0_row10_col12, #T_680f0_row11_col3 {
#   background-color: #96fca7;
#   color: #000000;
# }
# #T_680f0_row1_col11, #T_680f0_row15_col0 {
#   background-color: #4af2cf;
#   color: #000000;
# }
# #T_680f0_row1_col12, #T_680f0_row4_col3, #T_680f0_row8_col14, #T_680f0_row13_col7, #T_680f0_row14_col18, #T_680f0_row16_col11 {
#   background-color: #08bee9;
#   color: #000000;
# }
# #T_680f0_row1_col13, #T_680f0_row7_col14, #T_680f0_row8_col10, #T_680f0_row15_col2 {
#   background-color: #3473f8;
#   color: #f1f1f1;
# }
# #T_680f0_row1_col15, #T_680f0_row4_col13, #T_680f0_row6_col17, #T_680f0_row15_col1 {
#   background-color: #425ffa;
#   color: #f1f1f1;
# }
# #T_680f0_row1_col16, #T_680f0_row2_col4, #T_680f0_row4_col17, #T_680f0_row14_col9 {
#   background-color: #04b0ed;
#   color: #f1f1f1;
# }
# #T_680f0_row1_col17 {
#   background-color: #70febc;
#   color: #000000;
# }
# #T_680f0_row2_col1 {
#   background-color: #b2f396;
#   color: #000000;
# }
# #T_680f0_row2_col3, #T_680f0_row3_col2, #T_680f0_row9_col10 {
#   background-color: #ff9850;
#   color: #000000;
# }
# #T_680f0_row2_col5, #T_680f0_row10_col1 {
#   background-color: #abf69b;
#   color: #000000;
# }
# #T_680f0_row2_col6, #T_680f0_row8_col3, #T_680f0_row8_col13 {
#   background-color: #10a2f0;
#   color: #f1f1f1;
# }
# #T_680f0_row2_col7, #T_680f0_row14_col0 {
#   background-color: #27dade;
#   color: #000000;
# }
# #T_680f0_row2_col8, #T_680f0_row6_col5 {
#   background-color: #6032fe;
#   color: #f1f1f1;
# }
# #T_680f0_row2_col9, #T_680f0_row9_col0 {
#   background-color: #f0c46c;
#   color: #000000;
# }
# #T_680f0_row2_col10 {
#   background-color: #fbb965;
#   color: #000000;
# }
# #T_680f0_row2_col11, #T_680f0_row3_col7 {
#   background-color: #4ef3cd;
#   color: #000000;
# }
# #T_680f0_row2_col12 {
#   background-color: #acf59a;
#   color: #000000;
# }
# #T_680f0_row2_col13, #T_680f0_row3_col13, #T_680f0_row5_col13, #T_680f0_row11_col18 {
#   background-color: #149df1;
#   color: #f1f1f1;
# }
# #T_680f0_row2_col15, #T_680f0_row13_col4, #T_680f0_row13_col5, #T_680f0_row13_col18, #T_680f0_row18_col12 {
#   background-color: #208ef4;
#   color: #f1f1f1;
# }
# #T_680f0_row2_col16, #T_680f0_row10_col4 {
#   background-color: #34e4d9;
#   color: #000000;
# }
# #T_680f0_row2_col17 {
#   background-color: #c8e688;
#   color: #000000;
# }
# #T_680f0_row2_col18, #T_680f0_row13_col11 {
#   background-color: #06aeed;
#   color: #f1f1f1;
# }
# #T_680f0_row3_col0, #T_680f0_row4_col18, #T_680f0_row10_col2 {
#   background-color: #ffb360;
#   color: #000000;
# }
# #T_680f0_row3_col1 {
#   background-color: #cbe486;
#   color: #000000;
# }
# #T_680f0_row3_col4, #T_680f0_row16_col7 {
#   background-color: #1fd3e1;
#   color: #000000;
# }
# #T_680f0_row3_col5 {
#   background-color: #6dfdbf;
#   color: #000000;
# }
# #T_680f0_row3_col6, #T_680f0_row9_col4, #T_680f0_row9_col15 {
#   background-color: #00b5eb;
#   color: #f1f1f1;
# }
# #T_680f0_row3_col8, #T_680f0_row6_col9, #T_680f0_row6_col11, #T_680f0_row18_col5 {
#   background-color: #445cfb;
#   color: #f1f1f1;
# }
# #T_680f0_row3_col9 {
#   background-color: #ff934d;
#   color: #000000;
# }
# #T_680f0_row3_col10 {
#   background-color: #ff5029;
#   color: #f1f1f1;
# }
# #T_680f0_row3_col11 {
#   background-color: #8efeac;
#   color: #000000;
# }
# #T_680f0_row3_col12, #T_680f0_row5_col17 {
#   background-color: #5df9c7;
#   color: #000000;
# }
# #T_680f0_row3_col15, #T_680f0_row11_col4, #T_680f0_row13_col15 {
#   background-color: #169bf2;
#   color: #f1f1f1;
# }
# #T_680f0_row3_col16 {
#   background-color: #3ae8d6;
#   color: #000000;
# }
# #T_680f0_row3_col17, #T_680f0_row9_col3 {
#   background-color: #ff964f;
#   color: #000000;
# }
# #T_680f0_row3_col18, #T_680f0_row4_col16, #T_680f0_row12_col18, #T_680f0_row16_col13 {
#   background-color: #22d6e0;
#   color: #000000;
# }
# #T_680f0_row4_col0, #T_680f0_row4_col2, #T_680f0_row14_col10, #T_680f0_row18_col7 {
#   background-color: #1e91f3;
#   color: #f1f1f1;
# }
# #T_680f0_row4_col1, #T_680f0_row7_col4, #T_680f0_row18_col11 {
#   background-color: #386df9;
#   color: #f1f1f1;
# }
# #T_680f0_row4_col5, #T_680f0_row6_col10 {
#   background-color: #4856fb;
#   color: #f1f1f1;
# }
# #T_680f0_row4_col7, #T_680f0_row13_col17, #T_680f0_row14_col17 {
#   background-color: #2489f5;
#   color: #f1f1f1;
# }
# #T_680f0_row4_col8 {
#   background-color: #4a53fb;
#   color: #f1f1f1;
# }
# #T_680f0_row4_col9, #T_680f0_row17_col13 {
#   background-color: #11a0f1;
#   color: #f1f1f1;
# }
# #T_680f0_row4_col10, #T_680f0_row16_col15 {
#   background-color: #0dc2e8;
#   color: #000000;
# }
# #T_680f0_row4_col12, #T_680f0_row5_col14 {
#   background-color: #2e7bf7;
#   color: #f1f1f1;
# }
# #T_680f0_row4_col15 {
#   background-color: #6e1cff;
#   color: #f1f1f1;
# }
# #T_680f0_row5_col0 {
#   background-color: #52f5cb;
#   color: #000000;
# }
# #T_680f0_row5_col1 {
#   background-color: #30e1da;
#   color: #000000;
# }
# #T_680f0_row5_col2 {
#   background-color: #b4f295;
#   color: #000000;
# }
# #T_680f0_row5_col3 {
#   background-color: #7affb7;
#   color: #000000;
# }
# #T_680f0_row5_col4, #T_680f0_row10_col15, #T

# %%
df.corr()['price'].sort_values()
# Out:
# <ipython-input-26-78b4f396fb2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['price'].sort_values()
# zipcode         -0.053203
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
X = df[['long']]
Y = df['price']
lm = LinearRegression()
lm
lm.fit(X,Y)
lm.score(X, Y)
# Out:
# 0.00046769430149007363

# %%
lm.fit(df[['sqft_living']],df['price'])
yhat_a = lm.predict(df[['sqft_living']])
print(yhat_a)
lm.score(df[['sqft_living']],df['price'])
# Out:
# [287555.06702451 677621.82640197 172499.40418656 ... 242655.29616092
#  405416.96554144 242655.29616092]
# 0.4928532179037931

# %%
from sklearn.linear_model import LinearRegression

# %%
x=df[["sqft_living"]]
y=df["price"]
lm=LinearRegression()
lm.fit(x,y)
lm.score(x,y)
# Out:
# 0.4928532179037931

# %%
df.drop("date",axis=1,inplace=True)

# %%
features =["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]

# %%
lm=LinearRegression()
X=df[features]
Y=df["price"]
lm.fit(X,Y)
lm.score(X,Y)
# Out:
# 0.6577225505542041

# %%
Input=[('scale',StandardScaler()),('polynomial', PolynomialFeatures(include_bias=False)),('model',LinearRegression())]

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

W = df[features]
y = df['price']
Input=[('scale',StandardScaler()),('polynomial', PolynomialFeatures(include_bias=False)),('model',LinearRegression())]
pipe = Pipeline(Input)
pipe.fit(W,y)
pipe.score(W,y)
# Out:
# 0.7513483302081219

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
print("done")
# Out:
# done

# %%
features =["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]    
X = df[features ]
Y = df['price']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=1)


print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 3242
# number of training samples: 18371

# %%
from sklearn.linear_model import Ridge

# %%
Ridge_test = Ridge(alpha = 0.1)
Ridge_test.fit(x_test, y_test)
Ridge_test.score(x_test, y_test)
# Out:
# 0.6538198016209279

# %%
pr = PolynomialFeatures(degree=2)
x_train_pr = pr.fit_transform(x_train)
x_test_pr = pr.fit_transform(x_test)
pr
Ridge_test.fit(x_train_pr, y_train)
Ridge_test.score(x_train_pr, y_train)
# Out:
# 0.7418393310996081
