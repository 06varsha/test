# %% [markdown]
# Task-8
#
# Name: Varsha Gupta
#
# Referral id: DIRSS3129

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv("Student_Marks.csv")
df
# Out:
#      number_courses  time_study   Marks
# 0                 3       4.508  19.202
# 1                 4       0.096   7.734
# 2                 4       3.133  13.811
# 3                 6       7.909  53.018
# 4                 8       7.811  55.299
# ..              ...         ...     ...
# 126               3       6.335  32.357
# 127               3       0.301   5.609
# 128               4       7.163  41.444
# 129               7       0.309  12.027
# 130               3       6.335  32.357
#
# [131 rows x 3 columns]

# %%
df.head(10)
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299
# 5               6       3.211  17.822
# 6               3       6.063  29.889
# 7               5       3.413  17.264
# 8               4       4.410  20.348
# 9               3       6.173  30.862

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  131 non-null    int64
#  1   time_study      127 non-null    float64
#  2   Marks           122 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 3.2 KB

# %%
df.describe()
# Out:
#        number_courses  time_study       Marks
# count      131.000000  127.000000  122.000000
# mean         5.251908    3.880661   23.427475
# std          1.820159    2.340316   13.812173
# min          2.000000    0.096000    5.609000
# 25%          4.000000    1.968000   12.151250
# 50%          5.000000    3.919000   19.680500
# 75%          7.000000    6.103000   32.076750
# max          8.000000    7.957000   55.299000

# %%
df.columns
# Out:
# Index(['number_courses', 'time_study', 'Marks'], dtype='object')

# %%
df.shape
# Out:
# (131, 3)

# %%
df.duplicated().sum()
# Out:
# 18

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# number_courses    0
# time_study        4
# Marks             9
# dtype: int64

# %%
df.nunique()
# Out:
# number_courses      7
# time_study         99
# Marks             100
# dtype: int64

# %%
plt.figure(dpi=100)
sns.barplot('Marks', 'number_courses', data = df);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(dpi=100)
sns.barplot('Marks', 'time_study', data = df);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(dpi=100)
sns.barplot('number_courses', 'time_study', data = df);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(dpi=100)
sns.barplot('number_courses', 'Marks', data = df);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(dpi=100)
sns.countplot(x='Marks',data=df)

# %%
plt.figure(dpi=100)
sns.countplot(x='time_study',data=df)

# %%
plt.figure(dpi=100)
sns.countplot(x='number_courses',data=df)

# %%
plt.figure(dpi=100)
sns.barplot(x='number_courses',y='Marks',hue='time_study',data=df)

# %%
plt.figure(dpi=100)
sns.countplot(x="Marks",hue="number_courses",data=df)

# %%
plt.figure(dpi=100)
sns.lineplot(df['time_study'],df['Marks'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(dpi=100)
sns.lineplot(df['number_courses'],df['Marks'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(dpi=100)
sns.boxplot(x='Marks',data=df)

# %%
plt.figure(dpi=100)
sns.boxplot(x='number_courses',y='Marks',data=df)

# %%
plt.figure(dpi=100)
sns.scatterplot("time_study","number_courses", data=df, color='black')
sns.lineplot("time_study","number_courses", data=df, color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(dpi=100)
sns.scatterplot("number_courses","Marks", data=df, color='black')
sns.lineplot("number_courses","Marks", data=df, color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(dpi=100)
sns.heatmap(df.corr())

# %%
plt.figure(figsize=(10,6))
sns.pairplot(df,x_vars=['number_courses'],y_vars=['time_study'],size=6,kind='scatter')
plt.xlabel('number_courses')
plt.ylabel('time_study')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(10,6))
sns.pairplot(df,x_vars=['number_courses'],y_vars=['Marks'],size=6,kind='scatter')
plt.xlabel('number_courses')
plt.ylabel('Marks')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]

# %%
X
# Out:
#      number_courses  time_study
# 0                 3       4.508
# 1                 4       0.096
# 2                 4       3.133
# 3                 6       7.909
# 4                 8       7.811
# ..              ...         ...
# 122               6       3.561
# 123               3       0.301
# 124               4       7.163
# 125               7       0.309
# 126               3       6.335
#
# [113 rows x 2 columns]

# %%
Y
# Out:
# 0      19.202
# 1       7.734
# 2      13.811
# 3      53.018
# 4      55.299
#         ...
# 122    19.128
# 123     5.609
# 124    41.444
# 125    12.027
# 126    32.357
# Name: Marks, Length: 113, dtype: float64

# %%
#Splitting
from sklearn.model_selection import train_test_split
## dependent & independent variables
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 5)

# %%
print("Training data shape: ", X_train.shape)
print("Testing data shape: ", X_test.shape)
# Out:
# Training data shape:  (84, 2)
# Testing data shape:  (29, 2)

# %%
print("Dependent variable training: ", Y_train.shape)
print("Dependent variable testing: ", Y_test.shape)
# Out:
# Dependent variable training:  (84,)
# Dependent variable testing:  (29,)
